# %%
import pandas as pd
import re
from nltk import word_tokenize
import nltk
import numpy as np
import random

# %% [markdown]
# This notebook was used to reduce the presence of the more shallow aspects of formality in the Grammarly/Yahoo dataset. Examples of these aspects are slang, misspellings and the like: we do not want our models to learn these characteristics in the place of lexical and syntactic markers of formality.

# %% [markdown]
# # import data

# %%
informal_to_formal_df = pd.read_pickle('data/informal_to_formal_df.pkl')
formal_to_informal_df = pd.read_pickle('data/formal_to_informal_df.pkl')

# %%
formal_to_informal_df[formal_to_informal_df['Dataset'] == 'train'].head()
# Out:
#                                                Original  \
# 3266                  I prefer to let the guy ask me.\n
# 3267      I suffer through verbal abuse from my wife.\n
# 3268        You will have more friends than you want.\n
# 3269  It's nice that you get to see pictures of who ...
# 3270                       I need to know what to do.\n
#
#                                                Target 0 Target 1 Target 2  \
# 3266  Sure, it's ok, but I always have let the guy a...      NaN      NaN
# 3267  Hmmm, I'm a guy suffering from verbal abuse fr...      NaN      NaN
# 3268   You will have more friends that you want... ;)\n      NaN      NaN
# 3269  It's nice, you get to see pictures of who you ...      NaN      NaN
# 3270                         I NEED TO KNOW WHAT 2 DO\n      NaN      NaN
#
#      Target 3              Category Dataset
# 3266      NaN  Family_Relationships   train
# 3267      NaN  Family_Relationships   train
# 3268      NaN  Family_Relationships   train
# 3269      NaN  Family_Relationships   train
# 3270      NaN  Family_Relationships   train

# %% [markdown]
# # implement rule-based approach

# %% [markdown]
# This section used both manual inspection of the dataset and inspiration from the paper published about the dataset to decide what should be normalized or changed about the sentences on a consistent basis.

# %% [raw]
# ### Covered in their rule-based system
# # Capitalization (51%)
# ## Capitalize 1st letter
# ## Capitalize letter I
# ## Proper nouns (NNP/NNPS)
# # Punctuation (69%)
# # Contractions (8%)
# ## Handcrafted contractions list (expand)
# # Lowercase (8%)
# ## Lowercase sentences with only uppercase letters
# # Normalization (61%)
# ## Slang
# ## Censor swear words
# # Repetitions (5%)
# ## Remove multiple characters/repetition (??? !!! reallllly)
#
# ### NOT covered in rule-based system
# # Delete fillers ("Well")
# # Completion (ellipsis)
# # Spelling (should do this)
# # Split Sentences

# %%
informal = formal_to_informal_df['Target 0']
formal = formal_to_informal_df['Original']

# %%
def normalize(sentence):
    # "chatspeak" to "normal" text
    sentence = re.sub(r'\bim\b', "I'm", sentence, flags=re.I) #re.I = ignore case when matching
    sentence = re.sub(r"\bi'm\b", "I'm", sentence)
    sentence = re.sub(r"\bive\b", "I've", sentence, flags=re.I)
    sentence = re.sub(r"\bi've\b", "I've", sentence)
    sentence = re.sub(r"\bill\b", "I'll", sentence, flags=re.I)
    sentence = re.sub(r"\bi'll\b", "I'll", sentence)
    sentence = re.sub(r"\bi\b", "I", sentence)
    sentence = re.sub(r"\bId\b", "I'd", sentence)
    sentence = re.sub(r"\br\b", "are", sentence, flags=re.I)
    sentence = re.sub(r"\bu\b", "you", sentence, flags=re.I)
    sentence = re.sub(r"\bur\b", "your", sentence, flags=re.I)
    sentence = re.sub(r"\burself\b", "yourself", sentence, flags=re.I)
    sentence = re.sub(r"\byoure\b", "you're", sentence, flags=re.I)
    sentence = re.sub(r"\buve\b", "you've", sentence, flags=re.I)
    sentence = re.sub(r"\bu've\b", "you've", sentence, flags=re.I)
    sentence = re.sub(r"\bull\b", "you'll", sentence, flags=re.I)
    sentence = re.sub(r"\bu'll\b", "you'll", sentence, flags=re.I)
    sentence = re.sub(r"\balot\b", "a lot", sentence, flags=re.I)
    sentence = re.sub(r"\bcant\b", "can't", sentence, flags=re.I)
    sentence = re.sub(r"\bisnt\b", "isn't", sentence, flags=re.I)
    sentence = re.sub(r"\bdont\b", "don't", sentence, flags=re.I)
    sentence = re.sub(r"\bthats\b", "that's", sentence, flags=re.I)
    sentence = re.sub(r"\btheyll\b", "they'll", sentence, flags=re.I)
    sentence = re.sub(r"\btheyre\b", "they're", sentence, flags=re.I)
    sentence = re.sub(r"\bhes\b", "he's", sentence, flags=re.I)
    sentence = re.sub(r"\bshes\b", "she's", sentence, flags=re.I)
    sentence = re.sub(r"\bshud\b", "should", sentence, flags=re.I)
    sentence = re.sub(r"\bshld\b", "should", sentence, flags=re.I)
    sentence = re.sub(r"\bcya\b", "see you", sentence, flags=re.I)
    sentence = re.sub(r"\bluv\b", "love", sentence, flags=re.I)
    sentence = re.sub(r"\bbtw\b", "by the way", sentence, flags=re.I)
    sentence = re.sub(r"\bb/c ", "because ", sentence, flags=re.I)
    sentence = re.sub(r"\bw/ ", "with ", sentence, flags=re.I)
    sentence = re.sub(r"\bw/o ", "without ", sentence, flags=re.I)
    sentence = re.sub(r"\bluv\b", "love", sentence, flags=re.I)
    sentence = re.sub(r"\bhavent\b", "haven't", sentence, flags=re.I)
    sentence = re.sub(r"\btuff\b", "tough", sentence, flags=re.I)
    sentence = re.sub(r"\bgurl\b", "girl", sentence, flags=re.I)
    sentence = re.sub(r"\bdoesnt\b", "doesn't", sentence, flags=re.I)
    sentence = re.sub(r"\blets\b", "let's", sentence, flags=re.I)
    sentence = re.sub(r"\btheres\b", "there's", sentence, flags=re.I)
    sentence = re.sub(r"\bwhats\b", "what's", sentence, flags=re.I)
    sentence = re.sub(r"\bwhut\b", "what", sentence, flags=re.I)
    sentence = re.sub(r"\balot\b", "a lot", sentence, flags=re.I)
    sentence = re.sub(r"\bcos\b", "because", sentence, flags=re.I)
    sentence = re.sub(r"\bcuz\b", "because", sentence, flags=re.I)
    sentence = re.sub(r"\bbcuz\b", "because", sentence, flags=re.I)
    sentence = re.sub(r"\bteh\b", "the", sentence, flags=re.I)
    sentence = re.sub(r"\bkewl\b", "cool", sentence, flags=re.I)
    sentence = re.sub(r"\bdat\b", "that", sentence, flags=re.I)
    sentence = re.sub(r"\bda\b", "the", sentence, flags=re.I)
    sentence = re.sub(r"\brite\b", "right", sentence, flags=re.I)
    sentence = re.sub(r"\bwont\b", "won't", sentence, flags=re.I)
    sentence = re.sub(r"\bryt\b", "right", sentence, flags=re.I)
    sentence = re.sub(r"\bcud\b", "could", sentence, flags=re.I)
    sentence = re.sub(r"\bcood\b", "could", sentence, flags=re.I)
    sentence = re.sub(r"\byur\b", "your", sentence, flags=re.I)
    sentence = re.sub(r"\bnd\b", "and", sentence, flags=re.I)
    sentence = re.sub(r"\bbout\b", "about", sentence, flags=re.I)
    sentence = re.sub(r"\bwat\b", "what", sentence, flags=re.I)
    sentence = re.sub(r"\bwht\b", "what", sentence, flags=re.I)
    sentence = re.sub(r"\bnite\b", "night", sentence, flags=re.I)
    sentence = re.sub(r"\bwanna\b", "want to", sentence, flags=re.I)
    sentence = re.sub(r"\bjuz\b", "just", sentence, flags=re.I)
    sentence = re.sub(r"\bb4\b", "before", sentence, flags=re.I)
    sentence = re.sub(r"\bdats\b", "that's", sentence, flags=re.I)
    sentence = re.sub(r"\bdey\b", "they", sentence, flags=re.I)
    sentence = re.sub(r"\bdeyr\b", "they're", sentence, flags=re.I)
    sentence = re.sub(r"\bcoz\b", "because", sentence, flags=re.I)
    
    if ' id is ' in sentence:
        sentence = sentence.replace(' id ', " ID ")
    else:
        sentence = sentence.replace(' id ', " I'd ")
    return sentence

def capital(sentence):
    # check if entire sentence is capitalized: if so lowercase all but 1st character
    if sentence == sentence.upper():
        sentence = sentence.capitalize()
    else:
        sentence = sentence[0].upper() + sentence[1:] # capitalize 1st letter
        # capitalize words with POS tag of NNP or NNPs
        # this doesn't seem to do anything for the moment, because NLTK mostly
        # only tags proper nouns which are ALREADY capitalized
#         text = word_tokenize(sentence)
#         tags = nltk.pos_tag(text)
#         for idx in range(len(text)):
#             if tags[idx][1] in ['NNP', 'NNPS']:
#                 sentence = sentence.replace(tags[idx][0],
#                                  tags[idx][0][0].upper() + tags[idx][0][1:])
#                 print(tags[idx][1] + ' ' + tags[idx][0])
    return sentence

def punctuate(sentence):
    # too much, none at all, spacing and punctuation issues
    sentence = re.sub(r'[\?\!]+(?=[\?\!])', '', sentence) # reduce extra punctuation marks
    sentence = re.sub(r'[\.]+[\.]', '... ', sentence) # turn more than 1 period into 3
    sentence = re.sub(r'\s+', ' ', sentence).strip() # remove extra whitespace
    sentence = re.sub(r'(?<=[\.,])(?=[^\s\.])', ' ', sentence) # handle comma and period with no following space
    sentence = re.sub(r"\. com", ".com", sentence) # fix URLs changed by previous command
    sentence = re.sub(r" , ", ", ", sentence)
    sentence = re.sub(r" \. ", ". ", sentence)
    return sentence

def repeat(sentence):
    # more than 3 of the same letter in a row -> make either 1 or 2 letters from it
    # not perfect, but likely to help
    # i'd find out what realllllllllllllly happened -> I would determine what really happened
    sentence = re.sub(r'([a-zA-Z])\1{2}', "\1", sentence)
    return sentence

def correct(sentence):
    # make sure input actually is a sentence, and apply above functions
    if type(sentence) == float:
        if np.isnan(sentence):
            return sentence
    sentence = capital(sentence)
    sentence = normalize(sentence)
    sentence = repeat(sentence)
    sentence = punctuate(sentence)
    return sentence

# %%
for i in range(10):
    n = random.randint(1, len(informal))
    print(informal[n] + correct(informal[n])+ '\n' + formal[n])
# Out:
# girls gotta do what they gotta do.
# Girls gotta do what they gotta do.
# Girls must do what they must.
#
# I go for a guys personality.
# I go for a guys personality.
# I go for men's personality.
#
# none, but i think their both corny
# None, but I think their both corny
# None, but it is my belief that they are both trite.
#
# I don't know but he can take me over anytime!
# I don't know but he can take me over anytime!
# I do not know, however he is welcome to take me over at any time.
#
# Ah, the old hump & dump.
# Ah, the old hump & dump.
# THE FAMILIAR SCENARIO OF HAVING SEX AND LEAVING THEM.
#
# ask her why she sez makes her feel giddy and alive.
# Ask her why she sez makes her feel giddy and alive.
# If you ask her why, she will say that it allows her to feel happy and alive.
#
# i just want to ask for opinions that would best fit my question.
# I just want to ask for opinions that would best fit my question.
# I merely would like to ask for opinions that best match my question.
#
# THE ONLY REASON YOU LIKE IT IS BECAUSE YOU HEARD IT AT JEFFY'S HOUSE!
# The only reason you like it is because you heard it at jeffy's house!
# Jeffy's house is where you heard it and enjoyed it.
#
# well it's april 1 I guess you got your answer.
# Well it's april 1 I guess you got your answer.
# It is April. Did you get your answer?
#
# You just about described every High School movie...
# You just about described every High School movie...
# The description you gave fits almost every movie made that was set in a high school.

# %%
corrected_df = formal_to_informal_df.copy()

# %%
corrected_df['Target 0'] =corrected_df['Target 0'].apply(correct)
corrected_df['Target 1'] =corrected_df['Target 1'].apply(correct)
corrected_df['Target 2'] =corrected_df['Target 2'].apply(correct)
corrected_df['Target 3'] =corrected_df['Target 3'].apply(correct)

# %%
def strip_whitespace(sentence):
    # remove any leading or trailing whitespace after the above changes
    sentence = re.sub(r'\s+', ' ', sentence).strip()
    return sentence

corrected_df['Original'] = corrected_df['Original'].apply(strip_whitespace)

# %%
corrected_df
# Out:
#                                                  Original  \
# 0           I mean that you have to really be her friend.
# 1                   Are you posing a rhetorical question?
# 2       Men pretend to love in order to have intercour...
# 3                             I do not intend to be mean.
# 4       I would estimate an average of 45% initially b...
# 5       Because some women send subtle messages to men...
# 6       Let us purchase coffee and converse and procee...
# 7           Also, i dislike it when my father is unhappy.
# 8                  Ask him if you should go see a doctor.
# 9         You can post more questioins on Yahoo! answers.
# 10      He probably has many things to worry about rig...
# 11      But I do not believe that he will be unfaithfu...
# 12                           Will I always feel that way?
# 13      However, he may enjoy all of the waiting, drea...
# 14                       Also, I would like to try again.
# 15               Some men shave, it depends on the woman.
# 16      Well, if you are really attracted to this guy,...
# 17      I am not certain whether he loves you, but he ...
# 18      I would invite you on a date but I live in Ore...
# 19                                Women are coomplicated.
# 20      I realize I am overly selective when it comes ...
# 21                 Doing that does sound rather feminine.
# 22      Sometimes, if the good outweighs the bad, then...
# 23               That is if both of you agree to do this.
# 24      One female, Michelle, who most likely would no...
# 25      Well, why do you like the one boy who picks on...
# 26      In addition, men sometimes think that they do ...
# 27      Alas, if a male inquires of you, do not be fri...
# 28                             Do I desire to be in love?
# 29      That's the name I applied to it. For what reas...
# ...                                                   ...
# 111236  If you are referring to a prisoner then I am u...
# 111237        The should produce one similar to that one.
# 111238               I think nearly anyone would suffice.
# 111239        I found "Pearl Harbor" to be a boring film.
# 111240  I'm not familiar with her but I am a fan of Rani.
# 111241  I really like Vitamin C. I also like Graduatio...
# 111242  I don't really know but I am thinking that Tay...
# 111243  Please don't get upset about the other questio...
# 111244  I may not like them but they were very nice an...
# 111245               I wasn't but I knew someone who was.
# 111246  Angelina Jolie was born on June 4, 1975 in Los...
# 111247  Besides, I am sure that you are an amazing roc...
# 111248     No, the book is all about Jesus and the Bible.
# 111249      It probably is not it, but it is still close!
# 111250  Baby, stand-up comedies are outdated, but I li...
# 111251                You'll drown. I've tried it before.
# 111252                   It's a central american country.
# 111253  I haven't seen it in a while, but I do recall ...
# 111254             It's an ideal song to get in the mood!
# 111255  I never watched it. I'm afraid she will succee...
# 111256         I have tried it before and almost drowned.
# 111257              That is a country in Central America.
# 111258  I have not seen that in a while but I do remem...
# 111259  I feel that the song is ideal when trying to g...
# 111260  I have never seen the show but I am worried th...
# 111261  This is amazing and funny. Please send your id...
# 111262  Visit yahoo.com, and click on music. From ther...
# 111263                          Please shave or try nair.
# 111264  She grew up to be a bad person, who rapes youn...
# 111265  I do have it. Please send me a message and I w...
#
#                                                  Target 0  \
# 0                        And I mean Really be her friend.
# 1                    Sounds like a rhetorical question :)
# 2       Men play at love to get sex, women play at sex...
# 3                                I don't want to be mean.
# 4       On average I'd say about 45% at first but than...
# 5       Because some women send men tiny messages with...
# 6       let's get coffee and chat and take it from there!
# 7                      I also hate seeing my dad unhappy.
# 8                                Ask him to go see a doc.
# 9                   Post more questions on Yahoo Answers!
# 10      Besides don't you think he has enough to worry...
# 11      But I don't htink that by not having sex with ...
# 12      Anyway my question is... Will I always feel th...
# 13      But he might enjoy all the waiting, dreaming &...
# 14                               And I want to try again.
# 15      Not all the time, sometimes men shave them, it...
# 16      Well if you really like this guy smile and mak...
# 17      I don't know about love, but he likes you for ...
# 18      I'd ask you out, but I live in Oregon and have...
# 19             I can onli say... women are complicated...
# 20      I know I'm overtly picky about people HOW CAN ...
# 21                         It does sound a little girlie.
# 22      Sometimes the difficulties are worth it if the...
# 23               That's if you both agreed on doing this.
# 24      One girl Michelle, who probably wouldn't mind ...
# 25       Well, if the one boy picks on you, why like him?
# 26      Also sometimes guys think they don't need you ...
# 27       But if a guy asks you don't be afraid to say NO.
# 28                               Do I want to be in love?
# 29                 (that's what I called it)... but, why?
# ...                                                   ...
# 111236  If you are talking about a prisoner I am not s...
# 111237                       They should make 1 like that
# 111238                           Any idiot would do :-) .
# 111239                 Pearl Harbor - what a boring movie
# 111240            I Don't know her I'm more of a Rani fan
# 111241  I really love Vitamin C. Graduation Song ( Fri...
# 111242  I guess taylor might be next in line to win it...
# 111243  Don't explode please :) um, regarding your oth...
# 111244               They were kool and big daddy though.
# 111245                    No, but I knew someone who was.
# 111246  Angelina jolie, born june 4 1975 los angeles c...
# 111247      Besides I bet you're an amazing rocker *wink*
# 111248     No, the book is all about jesus and the bible.
# 111249       It probably isn't it, but it is still close!
# 111250  Baby stand up comedies are outdated, I like Ji...
# 111251                    Drown because I tried it before
# 111252                   Its a country in central america
# 111253  I haven't seen it in a while, but I remember i...
# 111254   I think that it's ideal song to get in the mood!
# 111255  I never watch the show but I am afraid she wil...
# 111256                    Drown because I tried it before
# 111257                   Its a country in central america
# 111258  I haven't seen it in a while, but I remember i...
# 111259   I think that it's ideal song to get in the mood!
# 111260  I never watch the show but I am afraid she wil...
# 111261  Amzing, Hilarouus plz sendur ID so I can add y...
# 111262  Go to yahoo.com then click on music and type i...
# 111263        Hell yea shave that shit please or try nair
# 111264  She grew up to become an evil old person who r...
# 111265  I have it if you would like it... message me a...
#
#                                                  Target 1  \
# 0                                 Just be her BFF 4 real.
# 1                           Do you really want an answer?
# 2       Men fake love to get laid, women fake orgasms ...
# 3                           I wasn't trying to be a jerk.
# 4       It's a little less than 50/50 at the start, bu...
# 5       Some ladies just hint at what they want and ex...
# 6       How about we grab some Starbucks and talk, and...
# 7                           I hate seeing my daddy sad :(
# 8                      Ask him if you should go see a dr.
# 9                           Post more ?s on Yahoo Answers
# 10            Dontcha think he has enough to worry about?
# 11      I don't think he'll step out or dip if you don...
# 12                                Will I feel that fo eva
# 13      But he mite like all that teasing and skeezin ...
# 14                                   You needs 2 try agin
# 15                Some men will shave for the right chick
# 16                  If you like him smile and speak nice.
# 17               He likes ya but I don't know about love.
# 18      I'd date ya, but I'm in Oregon and don't know ...
# 19                                       Bitches be crazy
# 20            I'm too picky, about people, how do I stop?
# 21                               That sounds pretty girly
# 22       If the good is better than the bad, its worth it
# 23                              Only if both of you agree
# 24      This girl Michelle who don't care if her name'...
# 25      Well why you gotta like the one boy who messes...
# 26      AND, brothas don't b knowin how much they need...
# 27        If a dude hits on you don't be scared to say no
# 28                                         Do I want love
# 29                      That what I called it but why idk
# ...                                                   ...
# 111236                                                NaN
# 111237                                                NaN
# 111238                                                NaN
# 111239                                                NaN
# 111240                                                NaN
# 111241                                                NaN
# 111242                                                NaN
# 111243                                                NaN
# 111244                                                NaN
# 111245                                                NaN
# 111246                                                NaN
# 111247                                                NaN
# 111248                                                NaN
# 111249                                                NaN
# 111250                                                NaN
# 111251                                                NaN
# 111252                                                NaN
# 111253                                                NaN
# 111254                                                NaN
# 111255                                                NaN
# 111256                                                NaN
# 111257                                                NaN
# 111258                                                NaN
# 111259                                                NaN
# 111260                                                NaN
# 111261                                                NaN
# 111262                                                NaN
# 111263                                                NaN
# 111264                                                NaN
# 111265                                                NaN
#
#                                                  Target 2  \
# 0                              you have to be her friend.
# 1       That sounds more like a rhetorical question th...
# 2       Guys PRETEND to love so they can get laid, wom...
# 3                             I'm not tryin to be mean...
# 4       Prolly 45% at the start but when you get to no...
# 5                 Women send men mixed messages sometimes
# 6            Up fr coffee and chat then see what happens?
# 7                      Hate it when my dad is bummed out.
# 8             Ask him if you should see a doc or sumthin'
# 9         Hey, go hit up Yahoo answers with a bunch of Qs
# 10      Give him a break, you're not the center of the...
# 11      I don't think he'll leave or cheat if you don'...
# 12                          Will I always feel like that?
# 13           BUT he may like all the coyness and yearning
# 14                                And I want to try again
# 15      Some men shave because there women likes them ...
# 16      Well if you really like this guy smile and tal...
# 17      I'm not sure if he loves you but I do know for...
# 18      I would ask you out but I live in Oregon and I...
# 19      Women are complicated because that is how men ...
# 20        I'm overly selective with people. how do I stop
# 21                                      That sounds girly
# 22                    The good may be better than the bad
# 23                                 Only if you both agree
# 24      Michelle doesn't like being named. she don't b...
# 25                Why do you like the boy who bullies you
# 26           Men don't think they need you till your gone
# 27                 Ehh don’t be scared to tell a bro NO!
# 28                                    Is lov what I want?
# 29                  That’s the name but I’m not sure why.
# ...                                                   ...
# 111236                                                NaN
# 111237                                                NaN
# 111238                                                NaN
# 111239                                                NaN
# 111240                                                NaN
# 111241                                                NaN
# 111242                                                NaN
# 111243                                                NaN
# 111244                                                NaN
# 111245                                                NaN
# 111246                                                NaN
# 111247                                                NaN
# 111248                                                NaN
# 111249                                                NaN
# 111250                                                NaN
# 111251                                                NaN
# 111252                                                NaN
# 111253                                                NaN
# 111254                                                NaN
# 111255                                                NaN
# 111256                                                NaN
# 111257                                                NaN
# 111258                                                NaN
# 111259                                                NaN
# 111260                                                NaN
# 111261                                                NaN
# 111262                                                NaN
# 111263                                                NaN
# 111264                                                NaN
# 111265                                                NaN
#
#                                                  Target 3  \
# 0           You have to actually be her friend, for real.
# 1                Are you asking me a rhetorical question?
# 2       Dudes just act like they love a chick to get b...
# 3                                I didn't want to be mean
# 4       I guess it'd be around 45% to start with, but ...
# 5       Chicks like to beat around the bush instead of...
# 6         Let's grab some coffee, talk, and go from there
# 7               When my dad is not happy, it tears me up.
# 8       Just ask him if he thinks you should go to the...
# 9       You can use yahoo answers to ask many more que...
# 10      He probably just has other things on his mind ...
# 11      I don't think he gon leave you or cheat cus y'...
# 12      I feel like I'm gon always feel like that, am ...
# 13      I mean he could like all the playing an antici...
# 14                                    Let me do it again.
# 15        Some guys shave, but it depends on the woman...
# 16      If your really into this guy, just smile and b...
# 17             Idk if he LOVES you, but he def likes you!
# 18      I'd ask you out, but I'm in Oregon and IDK whe...
# 19                         Ah women are so complicated...
# 20      I'm too picky, I know, but I don't know how to...
# 21                                 Sure sounds a bit fem.
# 22      If there's more good than bad, then it might b...
# 23                  Only if the two of you agree on this.
# 24      Michelle says she believes in it... she doesn'...
# 25              Y do you like the 1 boy who picks on you?
# 26      Guys don't think they need you until your gone...
# 27      You shouldn't be afraid of saying no if a guy ...
# 28                              Is love something I want?
# 29                      Yeah, it's what I called it, why?
# ...                                                   ...
# 111236                                                NaN
# 111237                                                NaN
# 111238                                                NaN
# 111239                                                NaN
# 111240                                                NaN
# 111241                                                NaN
# 111242                                                NaN
# 111243                                                NaN
# 111244                                                NaN
# 111245                                                NaN
# 111246                                                NaN
# 111247                                                NaN
# 111248                                                NaN
# 111249                                                NaN
# 111250                                                NaN
# 111251                                                NaN
# 111252                                                NaN
# 111253                                                NaN
# 111254                                                NaN
# 111255                                                NaN
# 111256                                                NaN
# 111257                                                NaN
# 111258                                                NaN
# 111259                                                NaN
# 111260                                                NaN
# 111261                                                NaN
# 111262                                                NaN
# 111263                                                NaN
# 111264                                                NaN
# 111265                                                NaN
#
#                     Category Dataset
# 0       Family_Relationships    test
# 1       Family_Relationships    test
# 2       Family_Relationships    test
# 3       Family_Relationships    test
# 4       Family_Relationships    test
# 5       Family_Relationships    test
# 6       Family_Relationships    test
# 7       Family_Relationships    test
# 8       Family_Relationships    test
# 9       Family_Relationships    test
# 10      Family_Relationships    test
# 11      Family_Relationships    test
# 12      Family_Relationships    test
# 13      Family_Relationships    test
# 14      Family_Relationships    test
# 15      Family_Relationships    test
# 16      Family_Relationships    test
# 17      Family_Relationships    test
# 18      Family_Relationships    test
# 19      Family_Relationships    test
# 20      Family_Relationships    test
# 21      Family_Relationships    test
# 22      Family_Relationships    test
# 23      Family_Relationships    test
# 24      Family_Relationships    test
# 25      Family_Relationships    test
# 26      Family_Relationships    test
# 27      Family_Relationships    test
# 28      Family_Relationships    test
# 29      Family_Relationships    test
# ...                      ...     ...
# 111236   Entertainment_Music   train
# 111237   Entertainment_Music   train
# 111238   Entertainment_Music   train
# 111239   Entertainment_Music   train
# 111240   Entertainment_Music   train
# 111241   Entertainment_Music   train
# 111242   Entertainment_Music   train
# 111243   Entertainment_Music   train
# 111244   Entertainment_Music   train
# 111245   Entertainment_Music   train
# 111246   Entertainment_Music   train
# 111247   Entertainment_Music   train
# 111248   Entertainment_Music   train
# 111249   Entertainment_Music   train
# 111250   Entertainment_Music   train
# 111251   Entertainment_Music   train
# 111252   Entertainment_Music   train
# 111253   Entertainment_Music   train
# 111254   Entertainment_Music   train
# 111255   Entertainment_Music   train
# 111256   Entertainment_Music   train
# 111257   Entertainment_Music   train
# 111258   Entertainment_Music   train
# 111259   Entertainment_Music   train
# 111260   Entertainment_Music   train
# 111261   Entertainment_Music   train
# 111262   Entertainment_Music   train
# 111263   Entertainment_Music   train
# 111264   Entertainment_Music   train
# 111265   Entertainment_Music   train
#
# [111266 rows x 7 columns]

# %%
corrected_df.to_pickle('data/rule_based_corrected_df.pkl')
